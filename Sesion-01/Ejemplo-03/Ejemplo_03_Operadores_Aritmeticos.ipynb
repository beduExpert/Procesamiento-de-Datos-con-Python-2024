# %% [markdown]
# ### Operaciones con Enteros y Decimales
#
# Primero, definimos algunas variables con valores enteros y flotantes:
#
# ```python
# a = 10
# b = 5
# c = 2.5
# d = 3.1
# ```
#
# Ahora, realizamos operaciones básicas con estas variables:
#
# ```python
# # Suma de enteros
# suma_enteros = a + b
# print("Suma de enteros:", suma_enteros)  # Salida: 15
#
# # Suma de entero y decimal
# suma_mixta = a + c
# print("Suma de entero y decimal:", suma_mixta)  # Salida: 12.5
#
# # Multiplicación de decimales
# producto_decimales = c * d
# print("Producto de decimales:", producto_decimales)  # Salida: 7.75
#
# # División entera de entero por decimal
# division_entera = a // c
# print("División entera de entero por decimal:", division_entera)  # Salida: 4.0
# ```
#
# ### Operaciones Involucrando Booleanos
#
# Python trata `True` como 1 y `False` como 0 en operaciones aritméticas. Aquí algunos ejemplos:
#
# ```python
# verdadero = True
# falso = False
#
# # Suma de booleano y entero
# suma_booleano = verdadero + a
# print("Suma de booleano y entero:", suma_booleano)  # Salida: 11
#
# # Multiplicación de booleano y decimal
# multiplicacion_booleano = falso * d
# print("Multiplicación de booleano y decimal:", multiplicacion_booleano)  # Salida: 0.0
#
# # Exponente usando booleanos
# exponente_booleano = verdadero ** falso
# print("Exponente usando booleanos:", exponente_booleano)  # Salida: 1
# ```
#
# ### Ejemplo Combinado con Variables
#
# A continuación, un ejemplo que combina varios tipos de operaciones:
#
# ```python
# x = 8
# y = 2.5
# z = True
#
# resultado = (x * y) + (z ** x) - (y // z)
# print("Resultado combinado:", resultado)
# # Salida: 20.0, porque (8*2.5) + (1**8) - (2.5//1) = 20.0 + 1 - 2.5 = 20.0
# ```
#
# ### Práctica de Operaciones
#
# Calcular el promedio de tres números, mezclando enteros y flotantes:
#
# ```python
# num1 = 95
# num2 = 85.5
# num3 = 88
#
# promedio = (num1 + num2 + num3) / 3
# print("Promedio:", promedio)  # Salida: 89.5
# ```
#
# Estos ejemplos demuestran cómo puedes utilizar variables para realizar operaciones aritméticas en Python, abarcando una amplia gama de tipos de datos y combinando diferentes operaciones para lograr cálculos más complejos.

# %% [markdown]
# 🔥Estan preparados para el siguiente Reto?
